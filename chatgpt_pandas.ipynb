# %% [markdown]
# Here are **60 most probable Pandas coding interview questions** (20 Easy, 20 Medium, 20 Hard), tailored for data scientist roles with 5+ years of experience. Each question includes an **input table** and the **expected output**, but no solutions.
#
# ---
#
# ## 🟢 Easy (20 Questions)
#
# 1. **Filter rows where salary > 50000**
#    - Input:
#      | name  | salary |
#      |-------|--------|
#      | John  | 45000  |
#      | Alice | 55000  |
#    - Output:
#      | name  | salary |
#      |-------|--------|
#      | Alice | 55000  |
#
# 2. **Count missing values per column**
#    - Input:
#      | A   | B     |
#      |-----|-------|
#      | 1   | NaN   |
#      | NaN | 2     |
#    - Output:
#      | Column | MissingCount |
#      |--------|--------------|
#      | A      | 1            |
#      | B      | 1            |
#
# 3. **Drop duplicate rows**
#    - Input:
#      | id | name  |
#      |----|-------|
#      | 1  | John  |
#      | 2  | Alice |
#      | 1  | John  |
#    - Output:
#      | id | name  |
#      |----|-------|
#      | 1  | John  |
#      | 2  | Alice |
#
# 4. **Convert column to datetime**
#    - Input:
#      | date       |
#      |------------|
#      | 2021-01-01 |
#      | 2021-01-02 |
#    - Output:
#      Column `date` as datetime64.
#
# 5. **Rename columns**
#    - Input:
#      | a | b |
#      |---|---|
#      | 1 | 2 |
#    - Output:
#      | col1 | col2 |
#      |------|------|
#      | 1    | 2    |
#
# 6. **Find max in each column**
#    - Input:
#      | A | B |
#      |---|---|
#      | 1 | 5 |
#      | 3 | 2 |
#    - Output:
#      | A | B |
#      |---|---|
#      | 3 | 5 |
#
# 7. **Sort dataframe by column**
#    - Input:
#      | name  | age |
#      |-------|-----|
#      | John  | 34  |
#      | Alice | 30  |
#    - Output: Sorted by `age`
#
# 8. **Change column data type**
#    - Input:
#      | id |
#      |----|
#      | 1  |
#    - Output: `id` as string
#
# 9. **Get unique values of a column**
#    - Input:
#      | city     |
#      |----------|
#      | New York |
#      | Boston   |
#      | Boston   |
#    - Output: `['New York', 'Boston']`
#
# 10. **Select rows where column contains string "data"**
#     - Input:
#       | title        |
#       |--------------|
#       | data science |
#       | analyst      |
#     - Output:
#       | title        |
#       |--------------|
#       | data science |
#
# 11. **Get row count and column count**
# 12. **Add a new column as sum of two columns**
# 13. **Group by column and get mean**
# 14. **Check if dataframe has nulls**
# 15. **Replace missing values with 0**
# 16. **Check if column is numeric**
# 17. **Filter rows by date range**
# 18. **Set a specific column as index**
# 19. **Reset index**
# 20. **Drop a column**
#
# ---
#
# ## 🟡 Medium (20 Questions)
#
# 1. **Get top 2 highest salary per department**
#    - Input:
#      | name  | dept   | salary |
#      |-------|--------|--------|
#      | John  | Sales  | 50000  |
#      | Alice | Sales  | 60000  |
#      | Bob   | HR     | 40000  |
#    - Output: Top 2 per dept
#
# 2. **Pivot table with sum of sales by region and product**
# 3. **Forward fill missing values**
# 4. **Convert wide format to long format**
# 5. **Filter rows based on multiple conditions**
# 6. **Cumulative sum per group**
# 7. **Rolling average over 3 rows**
# 8. **Map categorical values to new values**
# 9. **Merge two dataframes on a key**
# 10. **Concatenate two dataframes vertically**
# 11. **Find difference between two datetime columns**
# 12. **Rank salaries within departments**
# 13. **Apply custom lambda function on a column**
# 14. **Flag outliers using IQR**
# 15. **Replace values using regex**
# 16. **Drop rows where a column has only NaNs**
# 17. **Group by two columns and aggregate**
# 18. **Find duplicate values in a column**
# 19. **Get column with max correlation with target**
# 20. **Sort by multiple columns**
#
# ---
#
# ## 🔴 Hard (20 Questions)
#
# 1. **Identify users who logged in on 3 consecutive days**
#    - Input:
#      | user_id | login_date  |
#      |---------|-------------|
#      | 1       | 2023-01-01  |
#      | 1       | 2023-01-02  |
#      | 1       | 2023-01-03  |
#    - Output:
#      | user_id |
#      |---------|
#      | 1       |
#
# 2. **Fill missing values using group mean**
# 3. **Find longest streak of activity per user**
# 4. **Window function to get previous purchase amount**
# 5. **Normalize values per group**
# 6. **Split column with delimiter into multiple columns**
# 7. **Unpivot multi-index dataframe**
# 8. **Merge and filter based on date overlap**
# 9. **Compare two dataframes and highlight differences**
# 10. **Impute missing time series data with linear interpolation**
# 11. **Calculate retention rate by cohort**
# 12. **Implement weighted average per group**
# 13. **Filter top N per group and aggregate remaining as “Others”**
# 14. **Extract email domain and count frequency**
# 15. **Multi-index aggregation and reformatting**
# 16. **Detect and label changes in categorical values over time**
# 17. **Find rows where one column is substring of another**
# 18. **Compute rolling correlation between two columns**
# 19. **Explode list column and perform group aggregation**
# 20. **Get median absolute deviation per group**
#
# ---
#
# Let me know if you'd like:
# - All 60 as a downloadable CSV or Excel.
# - Any specific question expanded.
# - Questions tailored to a real dataset (e.g., sales, banking, transactions).

# %% [markdown]
# Here are **60 hard-level pandas coding questions** tailored to real datasets commonly used in **sales, banking, and transactions**. Each question includes the **input schema** and **expected output**—no solutions, as requested. These are ideal for data scientist coding rounds with 5+ years of experience.
#
# ---
#
# ## 🔴 Section 1: Sales Dataset (20 Questions)
#
# Assume a `sales` table:
# ```plaintext
# | order_id | customer_id | product_id | product_category | order_date | quantity | unit_price | region |
# ```
#
# 1. **Calculate the top 3 customers by total sales per region**
#    - Output:
#      | region | customer_id | total_sales |
#
# 2. **Find products with no sales in the last 6 months**
# 3. **Determine the monthly growth rate of total sales**
# 4. **Calculate the average basket size (items/order) per customer**
# 5. **Get customers whose first order was in Q1 2022 and they made at least 3 more purchases later**
# 6. **Rank products by sales within each category per month**
# 7. **Calculate revenue lost due to returns using a `returns` table**
# 8. **Detect unusually high order values per region using z-score**
# 9. **Identify customers who only bought from one product category ever**
# 10. **Compute the reorder rate (repeat purchase rate) per customer**
# 11. **For each product, calculate month-over-month % change in quantity sold**
# 12. **Detect pricing anomalies (unit price too low/high compared to average for that product)**
# 13. **Calculate moving average of daily sales per product (window = 7)**
# 14. **Create a time series of daily revenue and fill missing dates with 0**
# 15. **Identify the day of the week with highest avg order value**
# 16. **Determine the median time between purchases per customer**
# 17. **Group by product and count the number of unique customers who purchased it**
# 18. **Compute sales contribution of top 5% customers (Pareto principle)**
# 19. **Calculate cumulative sales by product category within each region**
# 20. **Find customers whose total spend increased by at least 50% compared to previous year**
#
# ---
#
# ## 🔴 Section 2: Banking Dataset (20 Questions)
#
# Assume a `transactions` table:
# ```plaintext
# | transaction_id | customer_id | transaction_date | amount | transaction_type | merchant |
# ```
#
# 1. **Identify customers with more than 5 failed transactions in a month**
#    - Output:
#      | customer_id | month | failed_txns |
#
# 2. **Find the average transaction amount by weekday for each customer**
# 3. **Detect round-number transactions (e.g., $100, $1000) and count frequency**
# 4. **Compute average time gap between two transactions for each customer**
# 5. **Identify customers who transacted with more than 10 unique merchants in the last 30 days**
# 6. **Calculate standard deviation of transaction amount per customer per month**
# 7. **Detect customers who had their largest transaction between 2 AM – 4 AM**
# 8. **Compare spend in groceries vs travel category per customer**
# 9. **Find customers who spent more than $10K in a single merchant in any month**
# 10. **Classify each transaction as small, medium, or large using customer-specific percentiles**
# 11. **Detect potential fraud: large transaction followed by a small one within 1 hour**
# 12. **Get number of days since last transaction for each customer**
# 13. **Compute rolling average of spend (last 3 transactions) per customer**
# 14. **Find customers who increased monthly spend for 3 consecutive months**
# 15. **Label customers with high variability in transaction amount using MAD**
# 16. **Identify merchants who received money from >100 unique customers in a month**
# 17. **Calculate percent of total transactions done on weekends per customer**
# 18. **Identify customers with consistent monthly transactions (variance < threshold)**
# 19. **Find the most common transaction type per customer**
# 20. **Detect gaps in transaction sequences (e.g., missing transaction IDs)**
#
# ---
#
# ## 🔴 Section 3: E-Commerce Order/Click Dataset (20 Questions)
#
# Assume a `user_orders` and `click_logs` table:
# ```plaintext
# user_orders:
# | order_id | user_id | product_id | order_time | order_amount |
#
# click_logs:
# | click_id | user_id | product_id | click_time |
# ```
#
# 1. **Find users who clicked on a product but never ordered it**
#    - Output:
#      | user_id | product_id |
#
# 2. **Compute click-to-order conversion rate per product**
# 3. **Calculate average time from click to purchase per product**
# 4. **Find users who made a purchase within 5 minutes of clicking**
# 5. **Detect users who placed orders without clicking on the product**
# 6. **Create a funnel: clicks → cart → order using status column**
# 7. **Calculate time spent browsing before purchase per user**
# 8. **Identify the hour of day with highest conversion rate**
# 9. **For each user, find the most frequently purchased product**
# 10. **Label users who only purchase at night (10PM–5AM)**
# 11. **Group by user and compute median cart size**
# 12. **Detect bots: users who clicked more than 1000 times in a day**
# 13. **Compute session length for each user (click-to-click gap)**
# 14. **Find abandonment rate (added to cart but didn’t purchase)**
# 15. **Identify trends in top selling products by day of the week**
# 16. **Detect spike in product views followed by zero orders**
# 17. **Label loyal users: purchase every month for last 6 months**
# 18. **Find percent of returning users (multiple orders)**
# 19. **Determine click fraud: multiple users clicking same product at same timestamp**
# 20. **Calculate product diversity index (entropy of categories purchased) per user**
#
# ---
#
# Would you like these in a downloadable format like:
# - Excel (.xlsx)
# - CSV
# - PDF
# - Markdown
#
# Or broken into separate topics with schemas?
